# %%
import poblacionmendeliana #IMPORTAMOS EL MODULO CREADO
Num_generation = 501 # SE PONE EL NUMERO DE 500 GENERACIONES 
New_generation = [] # AQUI ESTA EL NUMERO DE GENERACION Y LA FRECUENCIA DE LOS ALELOS
for i in range(Num_generation): # RANGO DE GENERACIONES 
    new_genes = poblacionmendeliana.build_population(20,0.27) # POBLACION INICIAL DE 20 (N) CON UNA FRECUENCIA DE 0.27 (A)
    Fnew_genes = poblacionmendeliana.compute_frequencies(new_genes) # FRECUENCIA DE ALELOS
    mypop = (Fnew_genes) # GENERACIONES CREADAS
    New_generation.append(mypop)

# %%
print(New_generation)
# Out:
# [{'AA': 0, 'aa': 13, 'Aa': 3, 'aA': 4}, {'AA': 0, 'aa': 10, 'Aa': 4, 'aA': 6}, {'AA': 0, 'aa': 8, 'Aa': 6, 'aA': 6}, {'AA': 0, 'aa': 11, 'Aa': 5, 'aA': 4}, {'AA': 1, 'aa': 12, 'Aa': 5, 'aA': 2}, {'AA': 0, 'aa': 10, 'Aa': 6, 'aA': 4}, {'AA': 1, 'aa': 13, 'Aa': 2, 'aA': 4}, {'AA': 0, 'aa': 11, 'Aa': 8, 'aA': 1}, {'AA': 2, 'aa': 9, 'Aa': 4, 'aA': 5}, {'AA': 4, 'aa': 7, 'Aa': 3, 'aA': 6}, {'AA': 3, 'aa': 11, 'Aa': 3, 'aA': 3}, {'AA': 2, 'aa': 14, 'Aa': 2, 'aA': 2}, {'AA': 2, 'aa': 6, 'Aa': 3, 'aA': 9}, {'AA': 1, 'aa': 11, 'Aa': 5, 'aA': 3}, {'AA': 1, 'aa': 10, 'Aa': 1, 'aA': 8}, {'AA': 1, 'aa': 11, 'Aa': 4, 'aA': 4}, {'AA': 1, 'aa': 8, 'Aa': 7, 'aA': 4}, {'AA': 1, 'aa': 13, 'Aa': 4, 'aA': 2}, {'AA': 2, 'aa': 11, 'Aa': 2, 'aA': 5}, {'AA': 1, 'aa': 9, 'Aa': 5, 'aA': 5}, {'AA': 2, 'aa': 11, 'Aa': 5, 'aA': 2}, {'AA': 0, 'aa': 12, 'Aa': 5, 'aA': 3}, {'AA': 3, 'aa': 12, 'Aa': 2, 'aA': 3}, {'AA': 4, 'aa': 10, 'Aa': 1, 'aA': 5}, {'AA': 4, 'aa': 9, 'Aa': 4, 'aA': 3}, {'AA': 0, 'aa': 5, 'Aa': 8, '
# ...
